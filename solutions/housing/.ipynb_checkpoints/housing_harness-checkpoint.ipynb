# %%
# Harness wide constants

data_folder = "./data"
dataset_name = "housing.data"

# %%
# Basic imports

import pandas as pd
import numpy as np

# %%
# Read in data

data_names = ["crim", "zn", "indus", "chas", "nox", "rm", "age", "dis", "rad", "tax", "ptratio", "b", "lstat", "medv"]

data = pd.read_csv(data_folder + "/" + dataset_name, delim_whitespace=True, names=data_names)

data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
data["medv"].min(), data["medv"].max()
# Out:
# (5.0, 50.0)

# %%
#
# 2. Preparing the Data
# 

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm

bounds = [5, 10, 20, 30, 40, 50]
colors = ["red", "blue", "green", "yellow", "purple", "black"]
cmap = ListedColormap(colors)
norm = BoundaryNorm(bounds, len(colors))

def plot_column(dataset_name, col, data, solution_col):
    fig, ax = plt.subplots()
    ax.title.set_text(dataset_name + " dataset - " + col)
    sc = ax.scatter(data.index, data[col], c=data[solution_col], cmap=cmap, norm=norm)
    fig.colorbar(sc, spacing="proportional")

# %%
for column in data:
    plot_column("housing", column, data, "medv")

# %%
#
# Data Preprocessing
#

use_dataset_var_2 = False
use_dataset_var_3 = False

data_numpy = data.to_numpy()

X = data_numpy[:,0:13].astype("float")
Y = data_numpy[:,13].astype("float")
#Y = Y.reshape(-1, 1)

# Dataset variant (optional)
if use_dataset_var_2:
    X = np.delete(X, 3, 1)
    X = np.delete(X, 3, 1)
    X = np.delete(X, 6, 1)
    X = np.delete(X, 6, 1)
    X = np.delete(X, 6, 1)
elif use_dataset_var_3:
    X = np.delete(X, 11, 1)

# %%
#
# 3. Train Models
#

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

data_rows, data_cols = X.shape

def baseline_model():
    model = Sequential()
    model.add(Dense(26, input_dim=data_cols, activation="relu"))
    model.add(Dense(1))
    model.compile(loss="mean_squared_error", optimizer="adam",metrics=["mse"])
    return model

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

epochs = 200
batch_size = 5

estimators = []
estimators.append(("standardize", StandardScaler()))
estimators.append(("mlp", KerasRegressor(build_fn = baseline_model, epochs=epochs, batch_size = batch_size)))

pipeline = Pipeline(estimators)

kfold = KFold(n_splits=10, shuffle=True)

# %%
results = cross_val_score(pipeline, X, Y, cv=kfold)
# Out:
# Epoch 1/200
# 91/91 [==============================] - 0s 981us/step - loss: 565.3268 - mse: 565.3268
# Epoch 2/200
# 91/91 [==============================] - 0s 935us/step - loss: 485.9454 - mse: 485.9454
# Epoch 3/200
# 91/91 [==============================] - 0s 1ms/step - loss: 411.4487 - mse: 411.4487
# Epoch 4/200
# 91/91 [==============================] - 0s 952us/step - loss: 337.4969 - mse: 337.4969
# Epoch 5/200
#  1/91 [..............................] - ETA: 0s - loss: 502.4650 - mse: 502.4650

# %%
print("Baseline = %.2f (%.2f)" % (results.mean(), results.std()))
# Out:
# Baseline = -12.19 (5.43)

# %%
# For fun, let's train a model and go a head and output the predictions. 

model = baseline_model()

model.fit(X, Y, epochs=epochs, batch_size=batch_size, verbose = 0)
# Out:
# Epoch 1/200
# 102/102 [==============================] - 0s 933us/step - loss: 1290.3922 - mse: 1290.3922
# Epoch 2/200
# 102/102 [==============================] - 0s 925us/step - loss: 157.1956 - mse: 157.1956
# Epoch 3/200
# 102/102 [==============================] - 0s 922us/step - loss: 95.7027 - mse: 95.7027
# Epoch 4/200
# 102/102 [==============================] - 0s 983us/step - loss: 83.2003 - mse: 83.2003
# Epoch 5/200
# 102/102 [==============================] - 0s 928us/step - loss: 72.7699 - mse: 72.7699
# Epoch 6/200
# 102/102 [==============================] - 0s 880us/step - loss: 63.5336 - mse: 63.5336
# Epoch 7/200
# 102/102 [==============================] - 0s 939us/step - loss: 60.6011 - mse: 60.6011
# Epoch 8/200
# 102/102 [==============================] - 0s 908us/step - loss: 56.0152 - mse: 56.0152
# Epoch 9/200
# 102/102 [==============================] - 0s 940us/step - loss: 51.8297 - mse: 51.8297
# Epoch 10/200
# ...

# %%
prediction = model.predict(X)
prediction

data_appended = data.copy()
data_appended['predicted_medv'] = prediction

# So we can peruse everything. 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

data_appended
# Out:
# <ipython-input-80-98a4a1b4361c>:11: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#          crim     zn  indus  chas     nox     rm    age      dis  rad    tax  \
# 0    0.00632   18.0   2.31   0     0.5380  6.575  65.2   4.0900   1    296.0
# 1    0.02731   0.0    7.07   0     0.4690  6.421  78.9   4.9671   2    242.0
# 2    0.02729   0.0    7.07   0     0.4690  7.185  61.1   4.9671   2    242.0
# 3    0.03237   0.0    2.18   0     0.4580  6.998  45.8   6.0622   3    222.0
# 4    0.06905   0.0    2.18   0     0.4580  7.147  54.2   6.0622   3    222.0
# 5    0.02985   0.0    2.18   0     0.4580  6.430  58.7   6.0622   3    222.0
# 6    0.08829   12.5   7.87   0     0.5240  6.012  66.6   5.5605   5    311.0
# 7    0.14455   12.5   7.87   0     0.5240  6.172  96.1   5.9505   5    311.0
# ...
